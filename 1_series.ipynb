# %%
import numpy as np
import pandas as pd

# %%
labels = ['a', 'b', 'c']
li = [10 ,20 ,30]
arr = np.array([10, 20, 30])
dict = {10:'a', 20:'b', 30:'c'}

# %%
pd.Series(li)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(li, labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(dict)
# Out:
# 10    a
# 20    b
# 30    c
# dtype: object
